# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import tensorflow.keras as keras
from tensorflow.keras.layers import BatchNormalization
import matplotlib.pyplot as plt
# %matplotlib inline

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

def build_mlp_bfact(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = BatchNormalization()(input_layer)
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
        else:
            x = BatchNormalization()(x)
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

def build_mlp_bfinp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = BatchNormalization()(input_layer)
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %% [markdown]
# ### 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異

# %%
LEARNING_RATE = 1e-3
EPOCHS = 15
BATCH_SIZE = [2, 16, 32, 128, 256]
MOMENTUM = 0.95

# %%
results = {}

for bsize in BATCH_SIZE:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with BatchSize = %i" % (bsize))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=bsize, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    exp_name_tag = "batch size-%s" % (str(bsize))
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with BatchSize = 2
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 95s 2ms/sample - loss: 2.3065 - accuracy: 0.1461 - val_loss: 2.1596 - val_accuracy: 0.2326
# Epoch 2/15
# 50000/50000 [==============================] - 96s 2ms/sample - loss: 2.2329 - accuracy: 0.1658 - val_loss: 2.1767 - val_accuracy: 0.2336
# Epoch 3/15
# 50000/50000 [==============================] - 108s 2ms/sample - loss: 2.2286 - accuracy: 0.1676 - val_loss: 2.2368 - val_accuracy: 0.2109
# Epoch 4/15
# 50000/50000 [==============================] - 95s 2ms/sample - loss: 2.2267 - accuracy: 0.1705 - val_loss: 2.7672 - val_accuracy: 0.1964
# Epoch 5/15
# 50000/50000 [==============================] - 102s 2ms/sample - loss: 2.2443 - accuracy: 0.1598 - val_loss: 5.0346 - val_accuracy: 0.2192
# Epoch 6/15
# 50000/50000 [==============================] - 97s 2ms/sample - loss: 2.2432 - accuracy: 0.1580 - val_loss: 4.0136 - val_accuracy: 0.2314
# Epoch 7/15
# 50000/50000 [==============================] - 104s 2ms/sample - loss: 2.2363 - accuracy: 0.1651 - val_loss: 31.4984 - val_accuracy: 0.1842
# Epoch 8/15
# 50000/50000 [==============================] - 97s 2ms/sample - loss: 2.2345 - accuracy: 0.1643 - val_loss: 22.0188 - val_accuracy: 0.2102
# Epoch 9/15
# 50000/50000 [==============================] - 98s 2ms/sample - loss: 2.2242 - accuracy: 0.1723 - val_loss: 163.2685 - val_accuracy: 0.2010
# Epoch 10/15
# 50000/50000 [==============================] - 100s 2ms/sample - loss: 2.2292 - accuracy: 0.1665 - val_loss: 1327.9738 - val_accuracy: 0.1812
# Epoch 11/15
# 50000/50000 [==============================] - 106s 2ms/sample - loss: 2.2316 - accuracy: 0.1665 - val_loss: 183.9787 - val_accuracy: 0.1867
# Epoch 12/15
# 50000/50000 [==============================] - 108s 2ms/sample - loss: 2.2232 - accuracy: 0.1716 - val_loss: 200.1324 - val_accuracy: 0.2164
# Epoch 13/15
# 50000/50000 [==============================] - 101s 2ms/sample - loss: 2.2248 - accuracy: 0.1721 - val_loss: 71.4814 - val_accuracy: 0.1786
# Epoch 14/15
# 50000/50000 [==============================] - 98s 2ms/sample - loss: 2.2294 - accuracy: 0.1672 - val_loss: 157.1041 - val_accuracy: 0.1865
# Epoch 15/15
# 50000/50000 [==============================] - 98s 2ms/sample - loss: 2.2321 - accuracy: 0.1653 - val_loss: 562.6055 - val_accuracy: 0.1734
# Experiment with BatchSize = 16
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 26s 520us/sample - loss: 1.8038 - accuracy: 0.3584 - val_loss: 1.6050 - val_accuracy: 0.4340
# Epoch 2/15
# 50000/50000 [==============================] - 26s 519us/sample - loss: 1.6501 - accuracy: 0.4136 - val_loss: 1.6172 - val_accuracy: 0.4269
# Epoch 3/15
# 50000/50000 [==============================] - 26s 523us/sample - loss: 1.5863 - accuracy: 0.4342 - val_loss: 1.5852 - val_accuracy: 0.4332
# Epoch 4/15
# 50000/50000 [==============================] - 26s 524us/sample - loss: 1.5514 - accuracy: 0.4496 - val_loss: 1.5357 - val_accuracy: 0.4535
# Epoch 5/15
# 50000/50000 [==============================] - 26s 515us/sample - loss: 1.5244 - accuracy: 0.4555 - val_loss: 1.4491 - val_accuracy: 0.4887
# Epoch 6/15
# 50000/50000 [==============================] - 27s 535us/sample - loss: 1.4982 - accuracy: 0.4696 - val_loss: 1.4488 - val_accuracy: 0.4880
# Epoch 7/15
# 50000/50000 [==============================] - 28s 554us/sample - loss: 1.4720 - accuracy: 0.4762 - val_loss: 1.4680 - val_accuracy: 0.4787
# Epoch 8/15
# 50000/50000 [==============================] - 28s 556us/sample - loss: 1.4448 - accuracy: 0.4872 - val_loss: 1.4188 - val_accuracy: 0.4950
# Epoch 9/15
# 50000/50000 [==============================] - 28s 568us/sample - loss: 1.4344 - accuracy: 0.4898 - val_loss: 1.4257 - val_accuracy: 0.4894
# Epoch 10/15
# 50000/50000 [==============================] - 27s 544us/sample - loss: 1.4141 - accuracy: 0.4995 - val_loss: 1.4423 - val_accuracy: 0.4983
# Epoch 11/15
# 50000/50000 [==============================] - 25s 500us/sample - loss: 1.4002 - accuracy: 0.5045 - val_loss: 1.5435 - val_accuracy: 0.4584
# Epoch 12/15
# 50000/50000 [==============================] - 25s 506us/sample - loss: 1.3813 - accuracy: 0.5075 - val_loss: 1.3790 - val_accuracy: 0.5169
# Epoch 13/15
# 50000/50000 [==============================] - 25s 496us/sample - loss: 1.3597 - accuracy: 0.5174 - val_loss: 1.4973 - val_accuracy: 0.4692
# Epoch 14/15
# 50000/50000 [==============================] - 25s 496us/sample - loss: 1.3488 - accuracy: 0.5211 - val_loss: 1.3958 - val_accuracy: 0.5069
# Epoch 15/15
# 50000/50000 [==============================] - 25s 500us/sample - loss: 1.3230 - accuracy: 0.5309 - val_loss: 1.4004 - val_accuracy: 0.5014
# Experiment with BatchSize = 32
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 15s 297us/sample - loss: 1.7337 - accuracy: 0.3902 - val_loss: 1.6044 - val_accuracy: 0.4277
# Epoch 2/15
# 50000/50000 [==============================] - 15s 301us/sample - loss: 1.5352 - accuracy: 0.4558 - val_loss: 1.5846 - val_accuracy: 0.4438
# Epoch 3/15
# 50000/50000 [==============================] - 20s 395us/sample - loss: 1.4531 - accuracy: 0.4842 - val_loss: 1.4849 - val_accuracy: 0.4737
# Epoch 4/15
# 50000/50000 [==============================] - 20s 394us/sample - loss: 1.4033 - accuracy: 0.5029 - val_loss: 1.5158 - val_accuracy: 0.4624
# Epoch 5/15
# 50000/50000 [==============================] - 19s 373us/sample - loss: 1.3690 - accuracy: 0.5135 - val_loss: 1.4750 - val_accuracy: 0.4730
# Epoch 6/15
# 50000/50000 [==============================] - 20s 391us/sample - loss: 1.3372 - accuracy: 0.5249 - val_loss: 1.5015 - val_accuracy: 0.4703
# Epoch 7/15
# 50000/50000 [==============================] - 19s 389us/sample - loss: 1.3194 - accuracy: 0.5314 - val_loss: 1.4749 - val_accuracy: 0.4756
# Epoch 8/15
# 50000/50000 [==============================] - 16s 328us/sample - loss: 1.3029 - accuracy: 0.5370 - val_loss: 1.5270 - val_accuracy: 0.4758
# Epoch 9/15
# 50000/50000 [==============================] - 17s 333us/sample - loss: 1.2928 - accuracy: 0.5387 - val_loss: 1.4543 - val_accuracy: 0.4938
# Epoch 10/15
# 50000/50000 [==============================] - 23s 458us/sample - loss: 1.2687 - accuracy: 0.5510 - val_loss: 1.5735 - val_accuracy: 0.4503
# Epoch 11/15
# 50000/50000 [==============================] - 23s 458us/sample - loss: 1.2465 - accuracy: 0.5573 - val_loss: 1.5854 - val_accuracy: 0.4498
# Epoch 12/15
# 50000/50000 [==============================] - 21s 427us/sample - loss: 1.2314 - accuracy: 0.5611 - val_loss: 1.4270 - val_accuracy: 0.4975
# Epoch 13/15
# 50000/50000 [==============================] - 19s 384us/sample - loss: 1.2162 - accuracy: 0.5660 - val_loss: 1.4176 - val_accuracy: 0.5030
# Epoch 14/15
# 50000/50000 [==============================] - 25s 498us/sample - loss: 1.1832 - accuracy: 0.5781 - val_loss: 1.4401 - val_accuracy: 0.4948
# Epoch 15/15
# 50000/50000 [==============================] - 22s 439us/sample - loss: 1.1605 - accuracy: 0.5863 - val_loss: 1.5421 - val_accuracy: 0.4723
# Experiment with BatchSize = 128
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 11s 224us/sample - loss: 1.7716 - accuracy: 0.3843 - val_loss: 1.6307 - val_accuracy: 0.4256
# Epoch 2/15
# 50000/50000 [==============================] - 12s 231us/sample - loss: 1.4922 - accuracy: 0.4720 - val_loss: 1.6593 - val_accuracy: 0.4171
# Epoch 3/15
# 50000/50000 [==============================] - 10s 202us/sample - loss: 1.3927 - accuracy: 0.5075 - val_loss: 1.5723 - val_accuracy: 0.4373
# Epoch 4/15
# 50000/50000 [==============================] - 8s 163us/sample - loss: 1.3218 - accuracy: 0.5325 - val_loss: 1.5191 - val_accuracy: 0.4632
# Epoch 5/15
# 50000/50000 [==============================] - 9s 180us/sample - loss: 1.2629 - accuracy: 0.5553 - val_loss: 1.6037 - val_accuracy: 0.4384
# Epoch 6/15
# 50000/50000 [==============================] - 10s 196us/sample - loss: 1.2137 - accuracy: 0.5732 - val_loss: 1.5380 - val_accuracy: 0.4547
# Epoch 7/15
# 50000/50000 [==============================] - 10s 192us/sample - loss: 1.1630 - accuracy: 0.5903 - val_loss: 1.5017 - val_accuracy: 0.4732
# Epoch 8/15
# 50000/50000 [==============================] - 9s 183us/sample - loss: 1.1202 - accuracy: 0.6064 - val_loss: 1.4937 - val_accuracy: 0.4786
# Epoch 9/15
# 50000/50000 [==============================] - 9s 187us/sample - loss: 1.0838 - accuracy: 0.6213 - val_loss: 1.4878 - val_accuracy: 0.4838
# Epoch 10/15
# 50000/50000 [==============================] - 10s 203us/sample - loss: 1.0449 - accuracy: 0.6297 - val_loss: 1.4383 - val_accuracy: 0.4974
# Epoch 11/15
# 50000/50000 [==============================] - 10s 195us/sample - loss: 1.0058 - accuracy: 0.6475 - val_loss: 1.4939 - val_accuracy: 0.4872
# Epoch 12/15
# 50000/50000 [==============================] - 10s 203us/sample - loss: 0.9641 - accuracy: 0.6626 - val_loss: 1.4614 - val_accuracy: 0.5038
# Epoch 13/15
# 50000/50000 [==============================] - 11s 213us/sample - loss: 0.9368 - accuracy: 0.6721 - val_loss: 1.5688 - val_accuracy: 0.4742
# Epoch 14/15
# 50000/50000 [==============================] - 10s 195us/sample - loss: 0.9092 - accuracy: 0.6830 - val_loss: 1.5820 - val_accuracy: 0.4751
# Epoch 15/15
# 50000/50000 [==============================] - 10s 198us/sample - loss: 0.8815 - accuracy: 0.6895 - val_loss: 1.6194 - val_accuracy: 0.4797
# Experiment with BatchSize = 256
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 9s 178us/sample - loss: 1.8522 - accuracy: 0.3618 - val_loss: 1.7312 - val_accuracy: 0.3844
# Epoch 2/15
# 50000/50000 [==============================] - 8s 151us/sample - loss: 1.5361 - accuracy: 0.4608 - val_loss: 1.5865 - val_accuracy: 0.4386
# Epoch 3/15
# 50000/50000 [==============================] - 8s 154us/sample - loss: 1.4387 - accuracy: 0.4967 - val_loss: 1.5621 - val_accuracy: 0.4485
# Epoch 4/15
# 50000/50000 [==============================] - 7s 149us/sample - loss: 1.3694 - accuracy: 0.5198 - val_loss: 1.5589 - val_accuracy: 0.4467
# Epoch 5/15
# 50000/50000 [==============================] - 8s 156us/sample - loss: 1.3121 - accuracy: 0.5384 - val_loss: 1.5532 - val_accuracy: 0.4595
# Epoch 6/15
# 50000/50000 [==============================] - 7s 143us/sample - loss: 1.2607 - accuracy: 0.5572 - val_loss: 1.4704 - val_accuracy: 0.4795
# Epoch 7/15
# 50000/50000 [==============================] - 6s 120us/sample - loss: 1.2100 - accuracy: 0.5732 - val_loss: 1.4788 - val_accuracy: 0.4765
# Epoch 8/15
# 50000/50000 [==============================] - 6s 114us/sample - loss: 1.1683 - accuracy: 0.5900 - val_loss: 1.5496 - val_accuracy: 0.4572
# Epoch 9/15
# 50000/50000 [==============================] - 8s 151us/sample - loss: 1.1287 - accuracy: 0.6021 - val_loss: 1.4925 - val_accuracy: 0.4779
# Epoch 10/15
# 50000/50000 [==============================] - 8s 161us/sample - loss: 1.0885 - accuracy: 0.6192 - val_loss: 1.5079 - val_accuracy: 0.4831
# Epoch 11/15
# 50000/50000 [==============================] - 10s 192us/sample - loss: 1.0521 - accuracy: 0.6324 - val_loss: 1.4755 - val_accuracy: 0.4902
# Epoch 12/15
# 50000/50000 [==============================] - 8s 163us/sample - loss: 1.0151 - accuracy: 0.6463 - val_loss: 1.4989 - val_accuracy: 0.4861
# Epoch 13/15
# 50000/50000 [==============================] - 8s 163us/sample - loss: 0.9785 - accuracy: 0.6597 - val_loss: 1.5414 - val_accuracy: 0.4773
# Epoch 14/15
# 50000/50000 [==============================] - 8s 156us/sample - loss: 0.9470 - accuracy: 0.6726 - val_loss: 1.5251 - val_accuracy: 0.4882
# Epoch 15/15
# 50000/50000 [==============================] - 8s 168us/sample - loss: 0.9159 - accuracy: 0.6849 - val_loss: 1.6941 - val_accuracy: 0.4501

# %%
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ### 請嘗試將 BN 放在 Activation 之前，並比較訓練結果

# %%
results = {}

keras.backend.clear_session() # 把舊的 Graph 清掉
bsize = 512
print("Experiment with BN before Activaion")
model = build_mlp_bfact(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=bsize, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
exp_name_tag = "bn act-%s" % (str(bsize))
results[exp_name_tag] = {'train-loss': train_loss,
                         'valid-loss': valid_loss,
                         'train-acc': train_acc,
                         'valid-acc': valid_acc}
# Out:
# Experiment with BN before Activaion
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,250
# Trainable params: 1,746,570
# Non-trainable params: 7,680
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 11s 218us/sample - loss: 1.9829 - accuracy: 0.3090 - val_loss: 1.9911 - val_accuracy: 0.2895
# Epoch 2/15
# 50000/50000 [==============================] - 11s 217us/sample - loss: 1.6190 - accuracy: 0.4318 - val_loss: 1.7680 - val_accuracy: 0.3695
# Epoch 3/15
# 50000/50000 [==============================] - 10s 191us/sample - loss: 1.5041 - accuracy: 0.4733 - val_loss: 1.6073 - val_accuracy: 0.4269
# Epoch 4/15
# 50000/50000 [==============================] - 10s 199us/sample - loss: 1.4232 - accuracy: 0.5025 - val_loss: 1.5150 - val_accuracy: 0.4606
# Epoch 5/15
# 50000/50000 [==============================] - 9s 189us/sample - loss: 1.3581 - accuracy: 0.5271 - val_loss: 1.4690 - val_accuracy: 0.4765
# Epoch 6/15
# 50000/50000 [==============================] - 9s 187us/sample - loss: 1.3006 - accuracy: 0.5484 - val_loss: 1.4416 - val_accuracy: 0.4852
# Epoch 7/15
# 50000/50000 [==============================] - 9s 186us/sample - loss: 1.2501 - accuracy: 0.5670 - val_loss: 1.4259 - val_accuracy: 0.4954
# Epoch 8/15
# 50000/50000 [==============================] - 10s 205us/sample - loss: 1.2038 - accuracy: 0.5840 - val_loss: 1.4135 - val_accuracy: 0.4952
# Epoch 9/15
# 50000/50000 [==============================] - 10s 200us/sample - loss: 1.1608 - accuracy: 0.6007 - val_loss: 1.4031 - val_accuracy: 0.5027
# Epoch 10/15
# 50000/50000 [==============================] - 11s 211us/sample - loss: 1.1174 - accuracy: 0.6176 - val_loss: 1.3974 - val_accuracy: 0.5046
# Epoch 11/15
# 50000/50000 [==============================] - 9s 176us/sample - loss: 1.0772 - accuracy: 0.6323 - val_loss: 1.3919 - val_accuracy: 0.5082
# Epoch 12/15
# 50000/50000 [==============================] - 9s 171us/sample - loss: 1.0381 - accuracy: 0.6490 - val_loss: 1.3894 - val_accuracy: 0.5069
# Epoch 13/15
# 50000/50000 [==============================] - 9s 183us/sample - loss: 1.0007 - accuracy: 0.6634 - val_loss: 1.3904 - val_accuracy: 0.5102
# Epoch 14/15
# 50000/50000 [==============================] - 10s 199us/sample - loss: 0.9611 - accuracy: 0.6788 - val_loss: 1.3874 - val_accuracy: 0.5154
# Epoch 15/15
# 50000/50000 [==============================] - 11s 215us/sample - loss: 0.9247 - accuracy: 0.6921 - val_loss: 1.3919 - val_accuracy: 0.5162

# %%
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ### 請於 BN 放在 Input Layer 後，並比較結果

# %%
results = {}

keras.backend.clear_session() # 把舊的 Graph 清掉
bsize = 512
print("Experiment with BN before Input")
model = build_mlp_bfinp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=bsize, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
exp_name_tag = "bn inp-%s" % (str(bsize))
results[exp_name_tag] = {'train-loss': train_loss,
                         'valid-loss': valid_loss,
                         'train-acc': train_acc,
                         'valid-acc': valid_acc}
# Out:
# Experiment with BN before Input
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v2_3 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,762
# Trainable params: 1,746,826
# Non-trainable params: 7,936
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 12s 233us/sample - loss: 2.0172 - accuracy: 0.3222 - val_loss: 1.9818 - val_accuracy: 0.2972
# Epoch 2/15
# 50000/50000 [==============================] - 11s 220us/sample - loss: 1.5991 - accuracy: 0.4431 - val_loss: 1.7783 - val_accuracy: 0.3721
# Epoch 3/15
# 50000/50000 [==============================] - 10s 208us/sample - loss: 1.4823 - accuracy: 0.4841 - val_loss: 1.6091 - val_accuracy: 0.4347
# Epoch 4/15
# 50000/50000 [==============================] - 10s 198us/sample - loss: 1.3985 - accuracy: 0.5144 - val_loss: 1.5224 - val_accuracy: 0.4612
# Epoch 5/15
# 50000/50000 [==============================] - 10s 208us/sample - loss: 1.3282 - accuracy: 0.5411 - val_loss: 1.4818 - val_accuracy: 0.4775
# Epoch 6/15
# 50000/50000 [==============================] - 10s 194us/sample - loss: 1.2700 - accuracy: 0.5620 - val_loss: 1.4680 - val_accuracy: 0.4792
# Epoch 7/15
# 50000/50000 [==============================] - 10s 207us/sample - loss: 1.2146 - accuracy: 0.5824 - val_loss: 1.4515 - val_accuracy: 0.4865
# Epoch 8/15
# 50000/50000 [==============================] - 10s 196us/sample - loss: 1.1634 - accuracy: 0.6005 - val_loss: 1.4426 - val_accuracy: 0.4943
# Epoch 9/15
# 50000/50000 [==============================] - 10s 193us/sample - loss: 1.1137 - accuracy: 0.6215 - val_loss: 1.4370 - val_accuracy: 0.4949
# Epoch 10/15
# 50000/50000 [==============================] - 10s 195us/sample - loss: 1.0692 - accuracy: 0.6380 - val_loss: 1.4349 - val_accuracy: 0.4971
# Epoch 11/15
# 50000/50000 [==============================] - 10s 192us/sample - loss: 1.0203 - accuracy: 0.6560 - val_loss: 1.4316 - val_accuracy: 0.5013
# Epoch 12/15
# 50000/50000 [==============================] - 10s 199us/sample - loss: 0.9775 - accuracy: 0.6718 - val_loss: 1.4382 - val_accuracy: 0.5013
# Epoch 13/15
# 50000/50000 [==============================] - 8s 163us/sample - loss: 0.9332 - accuracy: 0.6883 - val_loss: 1.4405 - val_accuracy: 0.5044
# Epoch 14/15
# 50000/50000 [==============================] - 10s 191us/sample - loss: 0.8891 - accuracy: 0.7061 - val_loss: 1.4457 - val_accuracy: 0.5049
# Epoch 15/15
# 50000/50000 [==============================] - 10s 200us/sample - loss: 0.8470 - accuracy: 0.7224 - val_loss: 1.4563 - val_accuracy: 0.5051

# %%
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
