# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import tensorflow.keras as keras
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import Callback
import matplotlib.pyplot as plt
# %matplotlib inline

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
# Record_fp_tp

class Record_tp_tn(Callback):
    def __init__(self, validation_data=()):
        super(Callback, self).__init__()
        self.validation_data = validation_data
       
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ['val_tp', 'val_tn']
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        val_tp = sum(y_true*y_pred)
        val_tn = sum((y_true==0) & (y_pred==0))
        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn

rec_tptn = Record_tp_tn(validation_data=(x_test, y_test))

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 4s 71us/sample - loss: 2.2282 - accuracy: 0.2617 - val_loss: 2.1677 - val_accuracy: 0.1932 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 2/25
# 50000/50000 [==============================] - 3s 60us/sample - loss: 1.7687 - accuracy: 0.3817 - val_loss: 1.9864 - val_accuracy: 0.3060 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 3/25
# 50000/50000 [==============================] - 3s 62us/sample - loss: 1.6410 - accuracy: 0.4243 - val_loss: 1.8203 - val_accuracy: 0.3821 - val_tp: 7.0000 - val_tn: 1000.0000
# Epoch 4/25
# 50000/50000 [==============================] - 3s 65us/sample - loss: 1.5669 - accuracy: 0.4527 - val_loss: 1.7183 - val_accuracy: 0.4123 - val_tp: 89.0000 - val_tn: 1000.0000
# Epoch 5/25
# 50000/50000 [==============================] - 3s 64us/sample - loss: 1.5141 - accuracy: 0.4704 - val_loss: 1.6444 - val_accuracy: 0.4298 - val_tp: 242.0000 - val_tn: 998.0000
# Epoch 6/25
# 50000/50000 [==============================] - 3s 65us/sample - loss: 1.4701 - accuracy: 0.4863 - val_loss: 1.5778 - val_accuracy: 0.4457 - val_tp: 628.0000 - val_tn: 998.0000
# Epoch 7/25
# 50000/50000 [==============================] - 3s 67us/sample - loss: 1.4333 - accuracy: 0.4973 - val_loss: 1.5481 - val_accuracy: 0.4541 - val_tp: 936.0000 - val_tn: 995.0000
# Epoch 8/25
# 50000/50000 [==============================] - 3s 70us/sample - loss: 1.4003 - accuracy: 0.5118 - val_loss: 1.5152 - val_accuracy: 0.4618 - val_tp: 1174.0000 - val_tn: 994.0000
# Epoch 9/25
# 50000/50000 [==============================] - 4s 70us/sample - loss: 1.3706 - accuracy: 0.5198 - val_loss: 1.5016 - val_accuracy: 0.4690 - val_tp: 1302.0000 - val_tn: 992.0000
# Epoch 10/25
# 50000/50000 [==============================] - 4s 72us/sample - loss: 1.3435 - accuracy: 0.5321 - val_loss: 1.4901 - val_accuracy: 0.4681 - val_tp: 1625.0000 - val_tn: 992.0000
# Epoch 11/25
# 50000/50000 [==============================] - 4s 73us/sample - loss: 1.3180 - accuracy: 0.5413 - val_loss: 1.4767 - val_accuracy: 0.4786 - val_tp: 1496.0000 - val_tn: 993.0000
# Epoch 12/25
# 50000/50000 [==============================] - 4s 76us/sample - loss: 1.2941 - accuracy: 0.5494 - val_loss: 1.4744 - val_accuracy: 0.4762 - val_tp: 2016.0000 - val_tn: 988.0000
# Epoch 13/25
# 50000/50000 [==============================] - 3s 68us/sample - loss: 1.2719 - accuracy: 0.5567 - val_loss: 1.4591 - val_accuracy: 0.4808 - val_tp: 1796.0000 - val_tn: 989.0000
# Epoch 14/25
# 50000/50000 [==============================] - 3s 64us/sample - loss: 1.2503 - accuracy: 0.5673 - val_loss: 1.4650 - val_accuracy: 0.4816 - val_tp: 1427.0000 - val_tn: 989.0000
# Epoch 15/25
# 50000/50000 [==============================] - 3s 69us/sample - loss: 1.2316 - accuracy: 0.5741 - val_loss: 1.4480 - val_accuracy: 0.4862 - val_tp: 2172.0000 - val_tn: 988.0000
# Epoch 16/25
# 50000/50000 [==============================] - 4s 72us/sample - loss: 1.2094 - accuracy: 0.5814 - val_loss: 1.4529 - val_accuracy: 0.4827 - val_tp: 1469.0000 - val_tn: 989.0000
# Epoch 17/25
# 50000/50000 [==============================] - 4s 70us/sample - loss: 1.1913 - accuracy: 0.5902 - val_loss: 1.4437 - val_accuracy: 0.4867 - val_tp: 2074.0000 - val_tn: 983.0000
# Epoch 18/25
# 50000/50000 [==============================] - 4s 72us/sample - loss: 1.1715 - accuracy: 0.5975 - val_loss: 1.4376 - val_accuracy: 0.4881 - val_tp: 1948.0000 - val_tn: 986.0000
# Epoch 19/25
# 50000/50000 [==============================] - 4s 85us/sample - loss: 1.1523 - accuracy: 0.6036 - val_loss: 1.4427 - val_accuracy: 0.4918 - val_tp: 2188.0000 - val_tn: 984.0000
# Epoch 20/25
# 50000/50000 [==============================] - 5s 108us/sample - loss: 1.1343 - accuracy: 0.6111 - val_loss: 1.4534 - val_accuracy: 0.4904 - val_tp: 2038.0000 - val_tn: 986.0000
# Epoch 21/25
# 50000/50000 [==============================] - 6s 126us/sample - loss: 1.1171 - accuracy: 0.6178 - val_loss: 1.4420 - val_accuracy: 0.4908 - val_tp: 2134.0000 - val_tn: 986.0000
# Epoch 22/25
# 50000/50000 [==============================] - 6s 114us/sample - loss: 1.1006 - accuracy: 0.6232 - val_loss: 1.4390 - val_accuracy: 0.4907 - val_tp: 2007.0000 - val_tn: 985.0000
# Epoch 23/25
# 50000/50000 [==============================] - 7s 130us/sample - loss: 1.0816 - accuracy: 0.6301 - val_loss: 1.4362 - val_accuracy: 0.4937 - val_tp: 1806.0000 - val_tn: 989.0000
# Epoch 24/25
# 50000/50000 [==============================] - 6s 111us/sample - loss: 1.0656 - accuracy: 0.6360 - val_loss: 1.4356 - val_accuracy: 0.4943 - val_tp: 1867.0000 - val_tn: 990.0000
# Epoch 25/25
# 50000/50000 [==============================] - 5s 110us/sample - loss: 1.0474 - accuracy: 0.6440 - val_loss: 1.4388 - val_accuracy: 0.4968 - val_tp: 1992.0000 - val_tn: 982.0000

# %%
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
